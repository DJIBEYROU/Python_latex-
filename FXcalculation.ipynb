# %%
pip install mplfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas-datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
pip install TA-Lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mplfinance as mpf
from pandas_datareader import data
import warnings
warnings.simplefilter('ignore')

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
yf.pdr_override()
start = '2022-01-01'
end = '2022-06-30'
df = yf.download(tickers='^N225', start = '2022-01-01', end = '2022-06-30', prepost = True, progress=False)
#df = yf.download(ticker, start, end)

# %%
mpf.plot(df, type='candle', figsize=(30,10), style='starsandstripes')

# %%
df.head(10)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-01-04  29098.410156  29323.789062  28954.560547  29301.789062
# 2022-01-05  29288.800781  29388.160156  29204.449219  29332.160156
# 2022-01-06  29136.750000  29158.949219  28487.869141  28487.869141
# 2022-01-07  28711.529297  28813.089844  28293.699219  28478.560547
# 2022-01-11  28380.900391  28473.470703  28089.490234  28222.480469
# 2022-01-12  28449.529297  28814.310547  28427.599609  28765.660156
# 2022-01-13  28658.220703  28660.449219  28444.960938  28489.130859
# 2022-01-14  28246.990234  28252.960938  27889.210938  28124.279297
# 2022-01-17  28332.720703  28449.990234  28274.179688  28333.519531
# 2022-01-18  28451.339844  28690.339844  28129.660156  28257.250000
#
#                Adj Close    Volume
# Date
# 2022-01-04  29301.789062  66000000
# 2022-01-05  29332.160156  78600000
# 2022-01-06  28487.869141  71600000
# 2022-01-07  28478.560547  75200000
# 2022-01-11  28222.480469  73700000
# ...

# %%
mpf.plot(df, type='candle', figsize=(30,10), style='yahoo')

# %%
mpf.plot(df, type='candle', figsize=(30,10), style='classic')

# %%
mpf.plot(df, type='candle', figsize=(30,10), style='charles')

# %%
mpf.plot(df, type='candle', figsize=(30,10), style='mike')

# %%
mpf.plot(df, type='candle', figsize=(30,10), style='starsandstripes')

# %%
#他にも、charlesやmike、starsandstripesなどがあります。お好きなグラフのスタイルを試してみてください
mpf.plot(df, type='candle', figsize=(30,10), style='yahoo')

# %%
mpf.plot(df, type='candle', figsize=(30,10), style='yahoo', volume=True)
